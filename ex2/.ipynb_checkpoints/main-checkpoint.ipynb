# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt

#%matplotlib inline

# %%
G = nx.read_adjlist('grid/adj')
F = nx.read_adjlist('wiki/adj')

# %% [markdown]
# # EX 3
#
# ## 3.1

# %% [markdown]
# N, E, density and the average degree for the us power grid:

# %%
N_G = G.number_of_nodes()
E_G = G.number_of_edges()
density_G = nx.density(G)

degrees = [val for (node, val) in G.degree()] 
avg_deg = np.mean(degrees)

print(N_G, E_G, density_G, avg_deg)
# Out:
# 4945 6598 0.0005397560871855786 2.6685540950455007

# %% [markdown]
# N, E, density and the average degree for the us de wiki:

# %%
N_F = F.number_of_nodes()
E_F = E = F.number_of_edges()
density_F = nx.density(F)

degrees = [val for (node, val) in F.degree()] 
avg_deg = np.mean(degrees)

print(N_F, E_F, density_F, avg_deg)
# Out:
# 569167 684334 4.224929364362406e-06 2.404686146596693

# %% [markdown]
# ## 3.2

# %%
cc = nx.connected_components(G)

[len(c) for c in sorted(cc, key=len, reverse=True)]
# Out:
# [4945]

# %%
cc = nx.connected_components(F)

[len(c) for c in sorted(cc, key=len, reverse=True)]
# Out:
# [569164, 3]

# %% [markdown]
# Network G (power grid) has only a single connected component of size 4945. Network F (wiki) has two connected components, one of size 569164 and the second largest is of size 3.

# %% [markdown]
# ## 3.3

# %%
nx.diameter(G)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 nx.diameter(G)
#
# File ~/.local/lib/python3.10/site-packages/networkx/algorithms/distance_measures.py:388, in diameter(G, e, usebounds)
#     386     return _extrema_bounding(G, compute="diameter")
#     387 if e is None:
# --> 388     e = eccentricity(G)
#     389 return max(e.values())
#
# File ~/.local/lib/python3.10/site-packages/networkx/algorithms/distance_measures.py:331, in eccentricity(G, v, sp)
#     329 for n in G.nbunch_iter(v):
#     330     if sp is None:
# --> 331         length = nx.single_source_shortest_path_length(G, n)
#     332         L = len(length)
#     333     else:
#
# File ~/.local/lib/python3.10/site-packages/networkx/algorithms/shortest_paths/unweighted.py:59, in single_source_shortest_path_length(G, source, cutoff)
#      57     cutoff = float("inf")
#      58 nextlevel = {source: 1}
# ---> 59 return dict(_single_shortest_path_length(G.adj, nextlevel, cutoff))
#
# File ~/.local/lib/python3.10/site-packages/networkx/algorithms/shortest_paths/unweighted.py:91, in _single_shortest_path_length(adj, firstlevel, cutoff)
#      89         return
#      90     for v in found:
# ---> 91         nextlevel.update(adj[v])
#      92     level += 1
#      93 del seen
#
# File ~/.local/lib/python3.10/site-packages/networkx/classes/coreviews.py:82, in AdjacencyView.__getitem__(self, name)
#      81 def __getitem__(self, name):
# ---> 82     return AtlasView(self._atlas[name])
#
# KeyboardInterrupt:

# %%
nx.average_shortest_path_length(G)

# %% [markdown]
# ## 3.4

# %%
import random

# %%
# Description is not clear, when I simply sample from the largest connected component I get a non connected component?
# I think there is not garantuee that a connected component of the sample size even exists
# therefore its not possible to solve this task


k = 100

largest_cc = max(nx.connected_components(F), key=len)

random.shuffle(largest)

subset_indices = largest[0:2000]

subset = F.subgraph(subset_indices)


#nx.average_shortest_path_length(subset)

# %% [markdown]
# ## 3.5

# %%
seq_abs = sorted((d for n, d in G.degree()), reverse=True)
seq = np.array(seq_abs)

pmf_y = np.bincount(seq)
total = np.sum(pmf_y)
pmf_y = pmf_y / total
pmf_x = np.linspace(0, len(pmf_y), num=len(pmf_y))


fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))
fig.suptitle("PMF for US power grid network", fontsize=14)
fig.tight_layout() 
ax1.set_xlabel('degree')
ax2.set_xlabel('degree')
ax1.set_ylabel('p(deg)')
ax2.set_ylabel('p(deg)')

ax1.plot(pmf_x, pmf_y)
ax1.set_title("lin lin plot")

ax2.plot(pmf_x, pmf_y)
ax2.set_yscale('log')
ax2.set_xscale('log')
ax2.set_title("log log plot")

plt.show()

# %%
seq_abs = sorted((d for n, d in F.degree()), reverse=True)
seq = np.array(seq_abs)

pmf_y = np.bincount(seq)
total = np.sum(pmf_y)
pmf_y = pmf_y / total
pmf_x = np.linspace(0, len(pmf_y), num=len(pmf_y))


fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))
fig.suptitle("PMF for DE WIKI Edits network", fontsize=14)
fig.tight_layout() 
ax1.set_xlabel('degree')
ax2.set_xlabel('degree')
ax1.set_ylabel('p(deg)')
ax2.set_ylabel('p(deg)')

ax1.plot(pmf_x, pmf_y)
ax1.set_title("lin lin plot")

ax2.plot(pmf_x, pmf_y)
ax2.set_yscale('log')
ax2.set_xscale('log')
ax2.set_title("log log plot")

plt.show()

# %% [markdown]
# ## 3.6

# %%
# Note: I think the probabilities are wrong in the example plots from the task

seq_abs = sorted((d for n, d in G.degree()), reverse=True)
seq = np.array(seq_abs)

pmf_y = np.bincount(seq)
total = np.sum(pmf_y)
pmf_y = pmf_y / total
ccdf_y = 1 - np.add.accumulate(pmf_y)
ccdf_x = np.linspace(0, len(pmf_y), num=len(pmf_y))

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))
fig.suptitle("CCDF for US POWER GRID network", fontsize=14)
fig.tight_layout() 
ax1.set_xlabel('degree')
ax2.set_xlabel('degree')
ax1.set_ylabel('p(deg)')
ax2.set_ylabel('p(deg)')

ax1.plot(ccdf_x, ccdf_y)
ax1.set_title("lin lin plot")

ax2.plot(ccdf_x, ccdf_y)
ax2.set_yscale('log')
ax2.set_xscale('log')
ax2.set_title("log log plot")

plt.show()

# %%
seq_abs = sorted((d for n, d in F.degree()), reverse=True)
seq = np.array(seq_abs)

pmf_y = np.bincount(seq)
total = np.sum(pmf_y)
pmf_y = pmf_y / total
ccdf_y = 1 - np.add.accumulate(pmf_y)
ccdf_x = np.linspace(0, len(pmf_y), num=len(pmf_y))
bb
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))
fig.suptitle("CCDF for DE WIKI EDITS network", fontsize=14)
fig.tight_layout() 
ax1.set_xlabel('degree')
ax2.set_xlabel('degree')
ax1.set_ylabel('p(deg)')
ax2.set_ylabel('p(deg)')

ax1.plot(ccdf_x, ccdf_y)
ax1.set_title("lin lin plot")

ax2.plot(ccdf_x, ccdf_y)
ax2.set_yscale('log')
ax2.set_xscale('log')
ax2.set_title("log log plot")

plt.show()

# %% [markdown]
# ## 3.7

# %%
import powerlaw # Power laws are probability distributions with the form:p(x)∝x−α

seq_abs = sorted((d for n, d in G.degree()), reverse=True)
seq = np.array(seq_abs)

pmf_y = np.bincount(seq) / N_G

fit = powerlaw.Fit(pmf_y) 

fig2 = fit.plot_pdf(color='b', linewidth=2)
fit.power_law.plot_pdf(color='g', linestyle='--', ax=fig2)
# Out:
# Calculating best minimal value for power law fit
# xmin progress: 92%
# Values less than or equal to 0 in data. Throwing out 0 or negative values
# <AxesSubplot: >

# %%
import powerlaw # Power laws are probability distributions with the form:p(x)∝x−α

seq_abs = sorted((d for n, d in G.degree()), reverse=True)
seq = np.array(seq_abs)

pmf_y = np.bincount(seq) / N_G

fit = powerlaw.Fit(pmf_y) 

fig2 = fit.plot_pdf(color='b', linewidth=2)
fit.power_law.plot_pdf(color='g', linestyle='--', ax=fig2)
